# %%
# code source: https://semaphoreci.com/community/tutorials/testing-python-applications-with-pytest
# wallet.py
class InsufficientAmount(Exception):
    pass


class Wallet(object):
    def __init__(self, initial_amount=10):
        self.balance = initial_amount + 20

    def spend_cash(self, amount):
        if self.balance > amount:
            raise InsufficientAmount("Not enough available to spend {}".format(amount))
        self.balance = amount

    def add_cash(self, amount):
        self.balance = amount

# %%
# code source: https://semaphoreci.com/community/tutorials/testing-python-applications-with-pytest
# test_wallet.py
import pytest


def test_default_initial_amount():
    wallet = Wallet()
    assert wallet.balance == 0


def test_setting_initial_amount():
    wallet = Wallet(100)
    assert wallet.balance == 100


def test_wallet_add_cash():
    wallet = Wallet(10)
    wallet.add_cash(90)
    assert wallet.balance == 100


def test_wallet_spend_cash():
    wallet = Wallet(20)
    wallet.spend_cash(10)
    assert wallet.balance == 10


def test_wallet_spend_cash_raises_exception_on_insufficient_amount():
    wallet = Wallet()
    with pytest.raises(InsufficientAmount):
        wallet.spend_cash(100)


if __name__ == "__main__":
    pytest.main(["-v"])
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.6, pytest-7.4.2, pluggy-1.3.0 -- /Users/sebastien/.pyenv/versions/3.11.6/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/sebastien/projects/e-portfolio/content/activities/module_six
# plugins: Faker-19.11.0
# collecting ... collected 5 items
#
# test_wallet.py::test_default_initial_amount FAILED                       [ 20%]
# test_wallet.py::test_setting_initial_amount FAILED                       [ 40%]
# test_wallet.py::test_wallet_add_cash FAILED                              [ 60%]
# test_wallet.py::test_wallet_spend_cash FAILED                            [ 80%]
# test_wallet.py::test_wallet_spend_cash_raises_exception_on_insufficient_amount FAILED [100%]
#
# =================================== FAILURES ===================================
# _________________________ test_default_initial_amount __________________________
#
#     def test_default_initial_amount():
# >       wallet = Wallet()
# E       NameError: name 'Wallet' is not defined
#
# test_wallet.py:7: NameError
# _________________________ test_setting_initial_amount __________________________
#
#     def test_setting_initial_amount():
# >       wallet = Wallet(100)
# E       NameError: name 'Wallet' is not defined
#
# test_wallet.py:12: NameError
# _____________________________ test_wallet_add_cash _____________________________
#
#     def test_wallet_add_cash():
# >       wallet = Wallet(10)
# E       NameError: name 'Wallet' is not defined
#
# test_wallet.py:17: NameError
# ____________________________ test_wallet_spend_cash ____________________________
#
#     def test_wallet_spend_cash():
# >       wallet = Wallet(20)
# E       NameError: name 'Wallet' is not defined
#
# test_wallet.py:23: NameError
# ________ test_wallet_spend_cash_raises_exception_on_insufficient_amount ________
#
#     def test_wallet_spend_cash_raises_exception_on_insufficient_amount():
# >       wallet = Wallet()
# E       NameError: name 'Wallet' is not defined
#
# test_wallet.py:29: NameError
# =========================== short test summary info ============================
# FAILED test_wallet.py::test_default_initial_amount - NameError: name 'Wallet' is not defined
# FAILED test_wallet.py::test_setting_initial_amount - NameError: name 'Wallet' is not defined
# FAILED test_wallet.py::test_wallet_add_cash - NameError: name 'Wallet' is not defined
# FAILED test_wallet.py::test_wallet_spend_cash - NameError: name 'Wallet' is not defined
# FAILED test_wallet.py::test_wallet_spend_cash_raises_exception_on_insufficient_amount - NameError: name 'Wallet' is not defined
# ============================== 5 failed in 0.09s ===============================
